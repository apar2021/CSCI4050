# %%
import pandas as pd
import numpy as np
import regex as re

# %%
# Read bulk_bookstore_dataset.csv
books = pd.read_csv("books_7k.csv")

book_publishers = [
    'Penguin Random House',
    'HarperCollins',
    'Hachette Livre',
    'Macmillan Publishers',
    'Simon & Schuster',
    'McGraw-Hill Education',
    'Scholastic Corporation',
    'Oxford University Press',
    'Pearson Education',
    'Bloomsbury Publishing',
    'Houghton Mifflin Harcourt',
    'Wiley',
    'Cambridge University Press',
    'Elsevier',
    'DK Publishing',
    'Hachette Book Group',
    'Cengage Learning',
    'Springer Nature',
    'Routledge',
    'SAGE Publications',
    'Tor Books',
    'Pan Macmillan',
    'Little, Brown and Company',
    'Alfred A. Knopf',
    'Doubleday',
    'Farrar, Straus and Giroux',
    'W. W. Norton & Company',
    'Zondervan',
    'University of Chicago Press',
    'Chronicle Books',
    "Random House Children's Books",
    "HarperCollins Children's Books",
    'Penguin Young Readers Group',
    'Harlequin',
    'Hay House',
    'Berkley Publishing Group',
    'Henry Holt and Company',
    'Ballantine Books',
    'Egmont Publishing'
]

editions_list = ['1st', '2nd', '3rd', '4th', '5th']

publishers = np.array(book_publishers)

# %%
books.head()
# Out:
#           isbn13      isbn10           title subtitle  \
# 0  9780002005883  0002005883          Gilead      NaN
# 1  9780002261982  0002261987    Spider's Web  A Novel
# 2  9780006163831  0006163831    The One Tree      NaN
# 3  9780006178736  0006178731  Rage of angels      NaN
# 4  9780006280897  0006280897  The Four Loves      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# 3  http://books.google.com/books/content?id=FKo2T...
# 4  http://books.google.com/books/content?id=XhQ5X...
#
#                                          description  published_year  \
# 0  A NOVEL THAT READERS and critics have been eag...          2004.0
# 1  A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2  Volume Two of Stephen Donaldson's acclaimed se...          1982.0
# 3  A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 4  Lewis' work on the nature of love divides love...          2002.0
#
#    average_rating  num_pages  ratings_count
# 0            3.85      247.0          361.0
# 1            3.83      241.0         5164.0
# 2            3.97      479.0          172.0
# 3            3.93      512.0        29532.0
# 4            4.15      170.0        33684.0

# %%
df_final = books[["title", "thumbnail", "isbn10", "authors", "categories", "published_year"]]
df_final.shape
# Out:
# (6810, 6)

# %%
df_final["edition"] = "1st"
df_final["status"] = "Available"
df_final["quantity"] = np.abs(np.random.normal(loc=100, scale=25, size=len(df_final))).astype(int)
df_final["selling_price"] = np.random.uniform(low=5, high=50, size=len(df_final)).round(2)
df_final["buying_price"] = df_final["selling_price"] * 0.75
df_final["publisher"] = np.random.choice(publishers, len(df_final))
df_final.head(10)
# Out:
# C:\Users\cownj\AppData\Local\Temp\ipykernel_3012\3651136933.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["edition"] = "1st"
# C:\Users\cownj\AppData\Local\Temp\ipykernel_3012\3651136933.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["status"] = "Available"
# C:\Users\cownj\AppData\Local\Temp\ipykernel_3012\3651136933.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["quantity"] = np.abs(np.random.normal(loc=100, scale=25, size=len(df_final))).astype(int)
# C:\Users\cownj\AppData\Local\Temp\ipykernel_3012\3651136933.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["selling_price"] = np.random.uniform(low=5, high=50, size=len(df_final)).round(2)
# C:\Users\cownj\AppData\Local\Temp\ipykernel_3012\3651136933.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["buying_price"] = df_final["selling_price"] * 0.75
#                     title                                          thumbnail  \
# 0                  Gilead  http://books.google.com/books/content?id=KQZCP...
# 1            Spider's Web  http://books.google.com/books/content?id=gA5GP...
# 2            The One Tree  http://books.google.com/books/content?id=OmQaw...
# 3          Rage of angels  http://books.google.com/books/content?id=FKo2T...
# 4          The Four Loves  http://books.google.com/books/content?id=XhQ5X...
# 5     The Problem of Pain  http://books.google.com/books/content?id=Kk-uV...
# 6        An Autobiography  http://books.google.com/books/content?id=c49GQ...
# 7  Empires of the Monsoon  http://books.google.com/books/content?id=MuPEQ...
# 8    The Gap Into Madness  http://books.google.com/books/content?id=4oXav...
# 9      Master of the Game  http://books.google.com/books/content?id=TkTYp...
#
#        isbn10                          authors  \
# 0  0002005883               Marilynne Robinson
# 1  0002261987  Charles Osborne;Agatha Christie
# 2  0006163831             Stephen R. Donaldson
# 3  0006178731                   Sidney Sheldon
# 4  0006280897              Clive Staples Lewis
# 5  0006280935              Clive Staples Lewis
# 6  0006353282                  Agatha Christie
# 7  0006380832                     Richard Hall
# 8  000647022X             Stephen R. Donaldson
# 9  0006472613                   Sidney Sheldon
#
#                             categories  published_year edition     status  \
# 0                              Fiction          2004.0     1st  Available
# 1        Detective and mystery stories          2000.0     1st  Available
# 2                     American fiction          1982.0     1st  Available
# 3                              Fiction          1993.0     1st  Available
# 4                       Christian life          2002.0     1st  Available
# 5                       Christian life          2002.0     1st  Available
# 6                     Authors, English          1977.0     1st  Available
# 7                         Africa, East          1998.0     1st  Available
# 8  Hyland, Morn (Fictitious character)          1994.0     1st  Available
# 9                    Adventure stories          1982.0     1st  Available
#
#    quantity  selling_price  buying_price                  publisher
# 0        97          17.72       13.2900  Little, Brown and Company
# 1        77           7.06        5.2950       Penguin Random House
# 2       115          16.49       12.3675                   Elsevier
# 3       132          44.77       33.5775            Springer Nature
# 4        95          28.82       21.6150   Berkley Publishing Group
# 5       105          19.92       14.9400             Hachette Livre
# 6       116           6.09        4.5675                  Tor Books
# 7       101          27.64       20.7300   Berkley Publishing Group
# 8       115          13.84       10.3800                  Tor Books
# 9       117          15.89       11.9175      McGraw-Hill Education
